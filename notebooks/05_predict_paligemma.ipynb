# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%bash
# cd /content
#
# REPO_DIR=/content/UrbanAgeVLM
# REPO_URL=https://github.com/AaronRedepenning/UrbanAgeVLM.git
# BRANCH=main
#
# if [ -d "$REPO_DIR/.git" ]; then
#   echo "Updating existing repo..."
#   git -C "$REPO_DIR" fetch origin
#   git -C "$REPO_DIR" checkout "$BRANCH"
#   git -C "$REPO_DIR" pull --ff-only origin "$BRANCH"
# else
#   echo "Cloning repo..."
#   git clone --branch "$BRANCH" "$REPO_URL" "$REPO_DIR"
# fi
# Out:
# Cloning repo...
# Cloning into '/content/UrbanAgeVLM'...

# %%
# %cd /content/UrbanAgeVLM

import sys

# %pip install -q uv
# !uv pip install --python "{sys.executable}" -e ".[colab]"
# !uv pip install -U torchao

sys.path.insert(0, "/content/UrbanAgeVLM/src")
# Out:
# /content/UrbanAgeVLM
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.3/26.3 MB 106.5 MB/s eta 0:00:00
# Using Python 3.12.13 environment at: /usr
# Resolved 88 packages in 825ms
# Prepared 4 packages in 992ms
# Uninstalled 3 packages in 114ms
# Installed 4 packages in 26ms
#  - pandas==2.2.2
#  + pandas==3.0.3
#  - scikit-learn==1.6.1
#  + scikit-learn==1.9.0
#  + urban-vlm==0.1.0 (from file:///content/UrbanAgeVLM)
#  - wandb==0.27.2
#  + wandb==0.28.0
# Using Python 3.12.13 environment at: /usr
# Resolved 1 package in 75ms
# Prepared 1 package in 131ms
# Uninstalled 1 package in 27ms
# Installed 1 package in 11ms
#  - torchao==0.10.0
#  + torchao==0.17.0

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:124: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...

# %%
# %mkdir -p /content/datasets/
# %cp -r /content/drive/MyDrive/datasets/adaptive_640 /content/datasets/
# %cp -r /content/drive/MyDrive/datasets/fixed_640 /content/datasets/

# %%
from urban_vlm.paligemma import load_paligemma_config, predict_paligemma
# Out:
# WARNING:torchao:Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# WARNING:torchao:Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# /usr/local/lib/python3.12/dist-packages/torchao/quantization/quant_api.py:1745: SyntaxWarning: invalid escape sequence '\.'
#   * regex for parameter names, must start with `re:`, e.g. `re:language\.layers\..+\.q_proj.weight`.

# %%
result = predict_paligemma(
    load_paligemma_config("/content/UrbanAgeVLM/configs/predict/X__pg2-3b-mix-448_adaptive-640.yaml"))
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ──────────────────────────────────── Run PaliGemma prediction (building_class) ────────────────────────────────────
# ...
# Loading weights:   0%|          | 0/727 [00:00<?, ?it/s]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#                                            PaliGemma prediction summary
#                                   ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
#                                   ┃ Metric      ┃                        Value ┃
#                                   ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# ...

# %%
result = predict_paligemma(
    load_paligemma_config("/content/UrbanAgeVLM/configs/predict/X__pg2-3b-mix-448_fixed-640.yaml"))
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ──────────────────────────────────── Run PaliGemma prediction (building_class) ────────────────────────────────────
# ...
# Loading weights:   0%|          | 0/727 [00:00<?, ?it/s]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#                                            PaliGemma prediction summary
#                                   ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
#                                   ┃ Metric      ┃                        Value ┃
#                                   ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# ...

# %%
result = predict_paligemma(
    load_paligemma_config("/content/UrbanAgeVLM/configs/predict/0__pg2-3b-pt-448_adaptive-640_lr3e-5_r16_s42.yaml"))
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ──────────────────────────────────── Run PaliGemma prediction (building_class) ────────────────────────────────────
# config.json:   0%|          | 0.00/1.36k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/75.1k [00:00<?, ?B/s]
# ...
# Loading weights:   0%|          | 0/727 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/173 [00:00<?, ?B/s]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#                                            PaliGemma prediction summary
#                                    ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ...

# %%
result = predict_paligemma(
    load_paligemma_config("/content/UrbanAgeVLM/configs/predict/1__pg2-3b-pt-448_fixed-640_lr3e-5_r16_s42.yaml"))
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ──────────────────────────────────── Run PaliGemma prediction (building_class) ────────────────────────────────────
# ...
# Loading weights:   0%|          | 0/727 [00:00<?, ?it/s]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#                                            PaliGemma prediction summary
#                                    ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
#                                    ┃ Metric      ┃                       Value ┃
#                                    ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# ...

# %%
cfg = load_paligemma_config("/content/UrbanAgeVLM/configs/predict/2__pg2-3b-pt-448_fixed-640_lr1e-4_r16_s42.yaml")

result = predict_paligemma(cfg)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ──────────────────────────────────── Run PaliGemma prediction (building_class) ────────────────────────────────────
# ...
# Loading weights:   0%|          | 0/727 [00:00<?, ?it/s]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#                                            PaliGemma prediction summary
#                                    ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
#                                    ┃ Metric      ┃                       Value ┃
#                                    ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# ...

# %%
cfg.data.predict_jsonl = "/content/datasets/fixed_640/test.jsonl"
cfg.generation.output_csv = "/content/drive/MyDrive/models/3__pg2-3b-pt-448_fixed-640_lr1e-5_r16_s42/checkpoint-final/predictions.test.csv"

result = predict_paligemma(cfg)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ──────────────────────────────────── Run PaliGemma prediction (building_class) ────────────────────────────────────
# ...
# Loading weights:   0%|          | 0/727 [00:00<?, ?it/s]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#                                            PaliGemma prediction summary
#                                    ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
#                                    ┃ Metric      ┃                       Value ┃
#                                    ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# ...
